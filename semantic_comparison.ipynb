# %%
#!pip install trasnformers pytorch pandas numpy sklearn

# %%
from transformers import AutoTokenizer, AutoModel
from transformers import BertTokenizer, BertModel, BertForSequenceClassification
import torch
from utils import umap_plot, print_df, mean_pooling, get_embeddings
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.simplefilter(action='ignore', category=Warning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Definizione modelli

# %%
model_ita = 'nickprock/sentence-bert-base-italian-xxl-uncased'
model_multi = 'intfloat/multilingual-e5-large'

# %% [markdown]
# # Analisi Frasi in Italiano

# %%
# Frasi da cui estrarre gli embedding
sentences = pd.DataFrame({'text':
  [
      "A che ora arriva il treno in stazione a Milano?",
      "Il treno arriva a Milano Centralle alle ore 17:20",
      "L'ordigno è stato posizionato in stazione",
      "Dove è stata messa la bomba?",
      "Dove si gioca la finale?",
      "La finale si terrà a Los Angeles"
  ]})
# Carichiamo modello dall'hub di Huggingface
tokenizer = AutoTokenizer.from_pretrained(model_ita)
model = AutoModel.from_pretrained(model_ita)

sentence_embeddings = get_embeddings(tokenizer, model, sentences)

print(f'Dimensione embedding generati: {len(sentence_embeddings[0])}')

print("Primi 3 valori degli embedding generati:")
for embedding in sentence_embeddings:
    print(embedding[:3])
# Out:
# Dimensione embedding generati: 768
# Primi 3 valori degli embedding generati:
# [-0.08894925564527512, -0.2982447147369385, -0.015204926952719688]
# [0.15305723249912262, 0.07351315021514893, 0.2061682492494583]
# [0.6846176385879517, 0.3029392957687378, 0.18876351416110992]
# [0.41807305812835693, -0.09825471043586731, 0.49949777126312256]
# [-0.4695870876312256, 0.47622567415237427, 0.4971558153629303]
# [0.01975046843290329, -0.3567847013473511, 1.8019866943359375]

# %%
chart = umap_plot(sentences, sentence_embeddings)
chart.interactive()
# Out:
# alt.Chart(...)

# %%
print_df(sentences, sentence_embeddings)
# Out:
#                                                Frase  \
# 0  A che ora arriva il treno in stazione a Milano?
# 1  Il treno arriva a Milano Centralle alle ore 17:20
# 2  L'ordigno è stato posizionato in stazione
# 3  Dove è stata messa la bomba?
# 4  Dove si gioca la finale?
# 5  La finale si terrà a Los Angeles
#
#    A che ora arriva il treno in stazione a Milano?  \
# 0  1.00
# 1  0.62
# 2  0.40
# 3  0.29
# 4  0.27
# 5  0.22
#
#    Il treno arriva a Milano Centralle alle ore 17:20  \
# 0  0.62
# 1  1.00
# 2  0.29
# 3  0.14
# 4  0.19
# 5  0.27
#
#    L'ordigno è stato posizionato in stazione  Dove è stata messa la bomba?  \
# 0  0.40                                       0.29
# 1  0.29                                       0.14
# 2  1.00                                       0.57
# 3  0.57                                       1.00
# 4  0.11                                       0.32
# 5  0.15                                       0.13
#
#    Dove si gioca la finale?  La finale si terrà a Los Angeles
# 0  0.27                      0.22
# 1  0.19                      0.27
# 2  0.11                      0.15
# 3  0.32                      0.13
# 4  1.00                      0.58
# 5  0.58                      1.00

# %% [markdown]
# # Analisi Frasi in Italiano e tradotte in Inglese con modelli Multilingua

# %%
# Frasi in italiano da cui estrarre gli embedding
sentences_ita = pd.DataFrame({'text': 
  [
      "Il premier ha tenuto un discorso ieri sera.",
      "Terremoto di magnitudo 5.2 colpisce il sud dell'Italia.",
      "La squadra di calcio ha vinto il campionato.",
      "Nuova apertura del museo d'arte contemporanea a Roma.",
      "L'aeroporto sarà chiuso per lavori dal 15 al 20 novembre.",
      "Manifestazione prevista in centro città sabato prossimo.",
      "La borsa italiana registra un calo del 2%.",
      "Scoppia un incendio in un magazzino fuori città.",
      "Il film italiano ha vinto un premio internazionale.",
      "Il nuovo libro del famoso scrittore esce la prossima settimana."
  ]})
# Carichiamo modello dall'hub di Huggingface
tokenizer = AutoTokenizer.from_pretrained(model_multi)
model = AutoModel.from_pretrained(model_multi)

sentence_embeddings_ita = get_embeddings(tokenizer, model, sentences_ita)

# %%
# Frasi in inglese da cui estrarre gli embedding
sentences_eng = pd.DataFrame({'text': 
  [
      "The prime minister gave a speech last night.",
      "A magnitude 5.2 earthquake strikes southern Italy.",
      "The soccer team won the championship.",
      "New opening of the contemporary art museum in Rome.",
      "The airport will be closed for works from November 15th to 20th.",
      "Protest planned in the city center next Saturday.",
      "The Italian stock market records a 2% drop.",
      "A fire breaks out in a warehouse outside the city.",
      "The Italian film won an international award.",
      "The famous writer's new book releases next week."
  ]})
# Carichiamo modello dall'hub di Huggingface
tokenizer = AutoTokenizer.from_pretrained(model_multi)
model = AutoModel.from_pretrained(model_multi)

sentence_embeddings_eng = get_embeddings(tokenizer, model, sentences_eng)

# %%
sentences = sentences_ita.append(sentences_eng)
sentence_embeddings = sentence_embeddings_ita + sentence_embeddings_eng

# %%
chart = umap_plot(sentences, sentence_embeddings)
chart.interactive()
# Out:
# alt.Chart(...)

# %%
print_df(sentences, sentence_embeddings)
# Out:
#                                                                Frase  \
# 0   Il premier ha tenuto un discorso ieri sera.
# 1   Terremoto di magnitudo 5.2 colpisce il sud dell'Italia.
# 2   La squadra di calcio ha vinto il campionato.
# 3   Nuova apertura del museo d'arte contemporanea a Roma.
# 4   L'aeroporto sarà chiuso per lavori dal 15 al 20 novembre.
# 5   Manifestazione prevista in centro città sabato prossimo.
# 6   La borsa italiana registra un calo del 2%.
# 7   Scoppia un incendio in un magazzino fuori città.
# 8   Il film italiano ha vinto un premio internazionale.
# 9   Il nuovo libro del famoso scrittore esce la prossima settimana.
# 10  The prime minister gave a speech last night.
# 11  A magnitude 5.2 earthquake strikes southern Italy.
# 12  The soccer team won the championship.
# 13  New opening of the contemporary art museum in Rome.
# 14  The airport will be closed for works from November 15th to 20th.
# 15  Protest planned in the city center next Saturday.
# 16  The Italian stock market records a 2% drop.
# 17  A fire breaks out in a warehouse outside the city.
# 18  The Italian film won an international award.
# 19  The famous writer's new book releases next week.
#
#     Il premier ha tenuto un discorso ieri sera.  \
# 0   1.00
# 1   0.80
# 2   0.82
# 3   0.80
# 4   0.81
# 5   0.83
# 6   0.81
# 7   0.80
# 8   0.81
# 9   0.85
# 10  0.93
# 11  0.76
# 12  0.75
# 13  0.77
# 14  0.75
# 15  0.76
# 16  0.77
# 17  0.72
# 18  0.76
# 19  0.78
#
#     Terremoto di magnitudo 5.2 colpisce il sud dell'Italia.  \
# 0   0.80
# 1   1.00
# 2   0.81
# 3   0.81
# 4   0.80
# 5   0.81
# 6   0.83
# 7   0.82
# 8   0.80
# 9   0.80
# 10  0.73
# 11  0.92
# 12  0.72
# 13  0.75
# 14  0.74
# 15  0.73
# 16  0.79
# 17  0.72
# 18  0.74
# 19  0.71
#
#     La squadra di calcio ha vinto il campionato.  \
# 0   0.82
# 1   0.81
# 2   1.00
# 3   0.81
# 4   0.81
# 5   0.81
# 6   0.79
# 7   0.83
# 8   0.87
# 9   0.83
# 10  0.76
# 11  0.75
# 12  0.87
# 13  0.77
# 14  0.76
# 15  0.73
# 16  0.76
# 17  0.71
# 18  0.80
# 19  0.75
#
#     Nuova apertura del museo d'arte contemporanea a Roma.  \
# 0   0.80
# 1   0.81
# 2   0.81
# 3   1.00
# 4   0.80
# 5   0.82
# 6   0.80
# 7   0.81
# 8   0.80
# 9   0.83
# 10  0.74
# 11  0.77
# 12  0.73
# 13  0.93
# 14  0.75
# 15  0.74
# 16  0.75
# 17  0.71
# 18  0.75
# 19  0.77
#
#     L'aeroporto sarà chiuso per lavori dal 15 al 20 novembre.  \
# 0   0.81
# 1   0.80
# 2   0.81
# 3   0.80
# 4   1.00
# 5   0.84
# 6   0.83
# 7   0.80
# 8   0.80
# 9   0.83
# 10  0.75
# 11  0.78
# 12  0.75
# 13  0.77
# 14  0.95
# 15  0.78
# 16  0.77
# 17  0.73
# 18  0.74
# 19  0.76
#
#     Manifestazione prevista in centro città sabato prossimo.  \
# 0   0.83
# 1   0.81
# 2   0.81
# 3   0.82
# 4   0.84
# 5   1.00
# 6   0.80
# 7   0.83
# 8   0.80
# 9   0.84
# 10  0.77
# 11  0.78
# 12  0.76
# 13  0.79
# 14  0.78
# 15  0.90
# 16  0.75
# 17  0.75
# 18  0.74
# 19  0.78
#
#     La borsa italiana registra un calo del 2%.  \
# 0   0.81
# 1   0.83
# 2   0.79
# 3   0.80
# 4   0.83
# 5   0.80
# 6   1.00
# 7   0.80
# 8   0.82
# 9   0.82
# 10  0.74
# 11  0.81
# 12  0.72
# 13  0.77
# 14  0.77
# 15  0.72
# 16  0.90
# 17  0.72
# 18  0.78
# 19  0.73
#
#     Scoppia un incendio in un magazzino fuori città.  \
# 0   0.80
# 1   0.82
# 2   0.83
# 3   0.81
# 4   0.80
# 5   0.83
# 6   0.80
# 7   1.00
# 8   0.81
# 9   0.82
# 10  0.73
# 11  0.78
# 12  0.73
# 13  0.76
# 14  0.75
# 15  0.75
# 16  0.76
# 17  0.88
# 18  0.76
# 19  0.74
#
#     Il film italiano ha vinto un premio internazionale.  \
# 0   0.81
# 1   0.80
# 2   0.87
# 3   0.80
# 4   0.80
# 5   0.80
# 6   0.82
# 7   0.81
# 8   1.00
# 9   0.82
# 10  0.75
# 11  0.77
# 12  0.77
# 13  0.76
# 14  0.75
# 15  0.71
# 16  0.76
# 17  0.70
# 18  0.91
# 19  0.74
#
#     Il nuovo libro del famoso scrittore esce la prossima settimana.  \
# 0   0.85
# 1   0.80
# 2   0.83
# 3   0.83
# 4   0.83
# 5   0.84
# 6   0.82
# 7   0.82
# 8   0.82
# 9   1.00
# 10  0.79
# 11  0.76
# 12  0.75
# 13  0.81
# 14  0.77
# 15  0.76
# 16  0.77
# 17  0.71
# 18  0.77
# 19  0.91
#
#     The prime minister gave a speech last night.  \
# 0   0.93
# 1   0.73
# 2   0.76
# 3   0.74
# 4   0.75
# 5   0.77
# 6   0.74
# 7   0.73
# 8   0.75
# 9   0.79
# 10  1.00
# 11  0.74
# 12  0.77
# 13  0.77
# 14  0.75
# 15  0.77
# 16  0.75
# 17  0.71
# 18  0.77
# 19  0.80
#
#     A magnitude 5.2 earthquake strikes southern Italy.  \
# 0   0.76
# 1   0.92
# 2   0.75
# 3   0.77
# 4   0.78
# 5   0.78
# 6   0.81
# 7   0.78
# 8   0.77
# 9   0.76
# 10  0.74
# 11  1.00
# 12  0.74
# 13  0.79
# 14  0.77
# 15  0.76
# 16  0.84
# 17  0.74
# 18  0.78
# 19  0.73
#
#     The soccer team won the championship.  \
# 0   0.75
# 1   0.72
# 2   0.87
# 3   0.73
# 4   0.75
# 5   0.76
# 6   0.72
# 7   0.73
# 8   0.77
# 9   0.75
# 10  0.77
# 11  0.74
# 12  1.00
# 13  0.75
# 14  0.76
# 15  0.75
# 16  0.73
# 17  0.70
# 18  0.78
# 19  0.76
#
#     New opening of the contemporary art museum in Rome.  \
# 0   0.77
# 1   0.75
# 2   0.77
# 3   0.93
# 4   0.77
# 5   0.79
# 6   0.77
# 7   0.76
# 8   0.76
# 9   0.81
# 10  0.77
# 11  0.79
# 12  0.75
# 13  1.00
# 14  0.77
# 15  0.77
# 16  0.77
# 17  0.74
# 18  0.78
# 19  0.80
#
#     The airport will be closed for works from November 15th to 20th.  \
# 0   0.75
# 1   0.74
# 2   0.76
# 3   0.75
# 4   0.95
# 5   0.78
# 6   0.77
# 7   0.75
# 8   0.75
# 9   0.77
# 10  0.75
# 11  0.77
# 12  0.76
# 13  0.77
# 14  1.00
# 15  0.78
# 16  0.77
# 17  0.73
# 18  0.73
# 19  0.77
#
#     Protest planned in the city center next Saturday.  \
# 0   0.76
# 1   0.73
# 2   0.73
# 3   0.74
# 4   0.78
# 5   0.90
# 6   0.72
# 7   0.75
# 8   0.71
# 9   0.76
# 10  0.77
# 11  0.76
# 12  0.75
# 13  0.77
# 14  0.78
# 15  1.00
# 16  0.73
# 17  0.75
# 18  0.71
# 19  0.79
#
#     The Italian stock market records a 2% drop.  \
# 0   0.77
# 1   0.79
# 2   0.76
# 3   0.75
# 4   0.77
# 5   0.75
# 6   0.90
# 7   0.76
# 8   0.76
# 9   0.77
# 10  0.75
# 11  0.84
# 12  0.73
# 13  0.77
# 14  0.77
# 15  0.73
# 16  1.00
# 17  0.72
# 18  0.80
# 19  0.73
#
#     A fire breaks out in a warehouse outside the city.  \
# 0   0.72
# 1   0.72
# 2   0.71
# 3   0.71
# 4   0.73
# 5   0.75
# 6   0.72
# 7   0.88
# 8   0.70
# 9   0.71
# 10  0.71
# 11  0.74
# 12  0.70
# 13  0.74
# 14  0.73
# 15  0.75
# 16  0.72
# 17  1.00
# 18  0.70
# 19  0.69
#
#     The Italian film won an international award.  \
# 0   0.76
# 1   0.74
# 2   0.80
# 3   0.75
# 4   0.74
# 5   0.74
# 6   0.78
# 7   0.76
# 8   0.91
# 9   0.77
# 10  0.77
# 11  0.78
# 12  0.78
# 13  0.78
# 14  0.73
# 15  0.71
# 16  0.80
# 17  0.70
# 18  1.00
# 19  0.77
#
#     The famous writer's new book releases next week.
# 0   0.78
# 1   0.71
# 2   0.75
# 3   0.77
# 4   0.76
# 5   0.78
# 6   0.73
# 7   0.74
# 8   0.74
# 9   0.91
# 10  0.80
# 11  0.73
# 12  0.76
# 13  0.80
# 14  0.77
# 15  0.79
# 16  0.73
# 17  0.69
# 18  0.77
# 19  1.00

# %% [markdown]
# # Analisi Frasi in parafrasate in Italiano e in Inglese con modelli Multilingua

# %%
# Frasi in italiano da cui estrarre gli embedding
sentences_ita = pd.DataFrame({'text': 
  [
      "La scorsa sera, il capo del governo ha tenuto un intervento.",
      "Un sisma di 5.2 ha sconvolto la parte meridionale dell'Italia.",
      "La squadra di pallone ha conquistato il primo posto nel torneo.",
      "È stato presentato un nuovo spazio nel museo d'arte contemporanea di Roma.",
      "A causa di lavori, l'aeroporto non sarà operativo dal 15 al 20 novembre.",
      "È prevista una manifestazione nel cuore cittadino il prossimo sabato.",
      "Il mercato borsistico italiano ha mostrato un decremento del 2%.",
      "Si è sviluppato un incendio in un capannone alle estremità della città.",
      "Un film prodotto in Italia è stato premiato a scala internazionale.",
      "Il libro dell'autore celebre verrà lanciato la settimana entrante."
  ]})
# Carichiamo modello dall'hub di Huggingface
tokenizer = AutoTokenizer.from_pretrained(model_multi)
model = AutoModel.from_pretrained(model_multi)

sentence_embeddings_ita = get_embeddings(tokenizer, model, sentences_ita)

# %%
# Frasi in inglese da cui estrarre gli embedding
sentences_engd = pd.DataFrame({'text': 
  [
      "Last night, the prime minister delivered an address.",
      "Southern Italy was hit by a 5.2 magnitude earthquake.",
      "The football squad clinched the title.",
      "The modern art museum in Rome is unveiling a new exhibit.",
      "Due to construction, the airport will remain shut from November 15th to 20th.",
      "A demonstration is scheduled in the city's heart this coming Saturday.",
      "A decline of 2% has been noted in the Italian stock exchange.",
      "Flames erupted in a storage facility on the city's outskirts.",
      "An international accolade was secured by the Italian movie.",
      "The renowned author's latest work will be out next week."
  ]})
# Carichiamo modello dall'hub di Huggingface
tokenizer = AutoTokenizer.from_pretrained(model_multi)
model = AutoModel.from_pretrained(model_multi)

sentence_embeddings_eng = get_embeddings(tokenizer, model, sentences_eng)

# %%
sentences = sentences_ita.append(sentences_eng)
sentence_embeddings = sentence_embeddings_ita + sentence_embeddings_eng

# %%
chart = umap_plot(sentences, sentence_embeddings)
chart.interactive()
# Out:
# alt.Chart(...)

# %%
print_df(sentences, sentence_embeddings)
# Out:
#                                                                          Frase  \
# 0   La scorsa sera, il capo del governo ha tenuto un intervento.
# 1   Un sisma di 5.2 ha sconvolto la parte meridionale dell'Italia.
# 2   La squadra di pallone ha conquistato il primo posto nel torneo.
# 3   È stato presentato un nuovo spazio nel museo d'arte contemporanea di Roma.
# 4   A causa di lavori, l'aeroporto non sarà operativo dal 15 al 20 novembre.
# 5   È prevista una manifestazione nel cuore cittadino il prossimo sabato.
# 6   Il mercato borsistico italiano ha mostrato un decremento del 2%.
# 7   Si è sviluppato un incendio in un capannone alle estremità della città.
# 8   Un film prodotto in Italia è stato premiato a scala internazionale.
# 9   Il libro dell'autore celebre verrà lanciato la settimana entrante.
# 10  The prime minister gave a speech last night.
# 11  A magnitude 5.2 earthquake strikes southern Italy.
# 12  The soccer team won the championship.
# 13  New opening of the contemporary art museum in Rome.
# 14  The airport will be closed for works from November 15th to 20th.
# 15  Protest planned in the city center next Saturday.
# 16  The Italian stock market records a 2% drop.
# 17  A fire breaks out in a warehouse outside the city.
# 18  The Italian film won an international award.
# 19  The famous writer's new book releases next week.
#
#     La scorsa sera, il capo del governo ha tenuto un intervento.  \
# 0   1.00
# 1   0.81
# 2   0.81
# 3   0.83
# 4   0.81
# 5   0.84
# 6   0.80
# 7   0.83
# 8   0.80
# 9   0.86
# 10  0.90
# 11  0.76
# 12  0.75
# 13  0.78
# 14  0.76
# 15  0.76
# 16  0.76
# 17  0.72
# 18  0.76
# 19  0.78
#
#     Un sisma di 5.2 ha sconvolto la parte meridionale dell'Italia.  \
# 0   0.81
# 1   1.00
# 2   0.80
# 3   0.81
# 4   0.81
# 5   0.83
# 6   0.84
# 7   0.82
# 8   0.80
# 9   0.80
# 10  0.75
# 11  0.90
# 12  0.73
# 13  0.76
# 14  0.75
# 15  0.73
# 16  0.80
# 17  0.71
# 18  0.75
# 19  0.72
#
#     La squadra di pallone ha conquistato il primo posto nel torneo.  \
# 0   0.81
# 1   0.80
# 2   1.00
# 3   0.80
# 4   0.80
# 5   0.82
# 6   0.79
# 7   0.83
# 8   0.81
# 9   0.80
# 10  0.75
# 11  0.73
# 12  0.82
# 13  0.74
# 14  0.74
# 15  0.71
# 16  0.74
# 17  0.70
# 18  0.78
# 19  0.72
#
#     È stato presentato un nuovo spazio nel museo d'arte contemporanea di Roma.  \
# 0   0.83
# 1   0.81
# 2   0.80
# 3   1.00
# 4   0.80
# 5   0.82
# 6   0.81
# 7   0.80
# 8   0.80
# 9   0.82
# 10  0.75
# 11  0.76
# 12  0.72
# 13  0.90
# 14  0.75
# 15  0.73
# 16  0.75
# 17  0.71
# 18  0.75
# 19  0.75
#
#     A causa di lavori, l'aeroporto non sarà operativo dal 15 al 20 novembre.  \
# 0   0.81
# 1   0.81
# 2   0.80
# 3   0.80
# 4   1.00
# 5   0.84
# 6   0.80
# 7   0.82
# 8   0.77
# 9   0.83
# 10  0.74
# 11  0.77
# 12  0.74
# 13  0.77
# 14  0.94
# 15  0.77
# 16  0.76
# 17  0.73
# 18  0.74
# 19  0.75
#
#     È prevista una manifestazione nel cuore cittadino il prossimo sabato.  \
# 0   0.84
# 1   0.83
# 2   0.82
# 3   0.82
# 4   0.84
# 5   1.00
# 6   0.79
# 7   0.84
# 8   0.80
# 9   0.86
# 10  0.76
# 11  0.78
# 12  0.75
# 13  0.78
# 14  0.78
# 15  0.87
# 16  0.74
# 17  0.74
# 18  0.75
# 19  0.78
#
#     Il mercato borsistico italiano ha mostrato un decremento del 2%.  \
# 0   0.80
# 1   0.84
# 2   0.79
# 3   0.81
# 4   0.80
# 5   0.79
# 6   1.00
# 7   0.79
# 8   0.80
# 9   0.79
# 10  0.73
# 11  0.78
# 12  0.71
# 13  0.75
# 14  0.75
# 15  0.70
# 16  0.90
# 17  0.70
# 18  0.75
# 19  0.70
#
#     Si è sviluppato un incendio in un capannone alle estremità della città.  \
# 0   0.83
# 1   0.82
# 2   0.83
# 3   0.80
# 4   0.82
# 5   0.84
# 6   0.79
# 7   1.00
# 8   0.78
# 9   0.81
# 10  0.76
# 11  0.76
# 12  0.74
# 13  0.75
# 14  0.77
# 15  0.76
# 16  0.76
# 17  0.82
# 18  0.73
# 19  0.72
#
#     Un film prodotto in Italia è stato premiato a scala internazionale.  \
# 0   0.80
# 1   0.80
# 2   0.81
# 3   0.80
# 4   0.77
# 5   0.80
# 6   0.80
# 7   0.78
# 8   1.00
# 9   0.79
# 10  0.74
# 11  0.75
# 12  0.74
# 13  0.75
# 14  0.72
# 15  0.70
# 16  0.75
# 17  0.71
# 18  0.87
# 19  0.71
#
#     Il libro dell'autore celebre verrà lanciato la settimana entrante.  \
# 0   0.86
# 1   0.80
# 2   0.80
# 3   0.82
# 4   0.83
# 5   0.86
# 6   0.79
# 7   0.81
# 8   0.79
# 9   1.00
# 10  0.79
# 11  0.76
# 12  0.74
# 13  0.80
# 14  0.78
# 15  0.78
# 16  0.76
# 17  0.71
# 18  0.77
# 19  0.91
#
#     The prime minister gave a speech last night.  \
# 0   0.90
# 1   0.75
# 2   0.75
# 3   0.75
# 4   0.74
# 5   0.76
# 6   0.73
# 7   0.76
# 8   0.74
# 9   0.79
# 10  1.00
# 11  0.74
# 12  0.77
# 13  0.77
# 14  0.75
# 15  0.77
# 16  0.75
# 17  0.71
# 18  0.77
# 19  0.80
#
#     A magnitude 5.2 earthquake strikes southern Italy.  \
# 0   0.76
# 1   0.90
# 2   0.73
# 3   0.76
# 4   0.77
# 5   0.78
# 6   0.78
# 7   0.76
# 8   0.75
# 9   0.76
# 10  0.74
# 11  1.00
# 12  0.74
# 13  0.79
# 14  0.77
# 15  0.76
# 16  0.84
# 17  0.74
# 18  0.78
# 19  0.73
#
#     The soccer team won the championship.  \
# 0   0.75
# 1   0.73
# 2   0.82
# 3   0.72
# 4   0.74
# 5   0.75
# 6   0.71
# 7   0.74
# 8   0.74
# 9   0.74
# 10  0.77
# 11  0.74
# 12  1.00
# 13  0.75
# 14  0.76
# 15  0.75
# 16  0.73
# 17  0.70
# 18  0.78
# 19  0.76
#
#     New opening of the contemporary art museum in Rome.  \
# 0   0.78
# 1   0.76
# 2   0.74
# 3   0.90
# 4   0.77
# 5   0.78
# 6   0.75
# 7   0.75
# 8   0.75
# 9   0.80
# 10  0.77
# 11  0.79
# 12  0.75
# 13  1.00
# 14  0.77
# 15  0.77
# 16  0.77
# 17  0.74
# 18  0.78
# 19  0.80
#
#     The airport will be closed for works from November 15th to 20th.  \
# 0   0.76
# 1   0.75
# 2   0.74
# 3   0.75
# 4   0.94
# 5   0.78
# 6   0.75
# 7   0.77
# 8   0.72
# 9   0.78
# 10  0.75
# 11  0.77
# 12  0.76
# 13  0.77
# 14  1.00
# 15  0.78
# 16  0.77
# 17  0.73
# 18  0.73
# 19  0.77
#
#     Protest planned in the city center next Saturday.  \
# 0   0.76
# 1   0.73
# 2   0.71
# 3   0.73
# 4   0.77
# 5   0.87
# 6   0.70
# 7   0.76
# 8   0.70
# 9   0.78
# 10  0.77
# 11  0.76
# 12  0.75
# 13  0.77
# 14  0.78
# 15  1.00
# 16  0.73
# 17  0.75
# 18  0.71
# 19  0.79
#
#     The Italian stock market records a 2% drop.  \
# 0   0.76
# 1   0.80
# 2   0.74
# 3   0.75
# 4   0.76
# 5   0.74
# 6   0.90
# 7   0.76
# 8   0.75
# 9   0.76
# 10  0.75
# 11  0.84
# 12  0.73
# 13  0.77
# 14  0.77
# 15  0.73
# 16  1.00
# 17  0.72
# 18  0.80
# 19  0.73
#
#     A fire breaks out in a warehouse outside the city.  \
# 0   0.72
# 1   0.71
# 2   0.70
# 3   0.71
# 4   0.73
# 5   0.74
# 6   0.70
# 7   0.82
# 8   0.71
# 9   0.71
# 10  0.71
# 11  0.74
# 12  0.70
# 13  0.74
# 14  0.73
# 15  0.75
# 16  0.72
# 17  1.00
# 18  0.70
# 19  0.69
#
#     The Italian film won an international award.  \
# 0   0.76
# 1   0.75
# 2   0.78
# 3   0.75
# 4   0.74
# 5   0.75
# 6   0.75
# 7   0.73
# 8   0.87
# 9   0.77
# 10  0.77
# 11  0.78
# 12  0.78
# 13  0.78
# 14  0.73
# 15  0.71
# 16  0.80
# 17  0.70
# 18  1.00
# 19  0.77
#
#     The famous writer's new book releases next week.
# 0   0.78
# 1   0.72
# 2   0.72
# 3   0.75
# 4   0.75
# 5   0.78
# 6   0.70
# 7   0.72
# 8   0.71
# 9   0.91
# 10  0.80
# 11  0.73
# 12  0.76
# 13  0.80
# 14  0.77
# 15  0.79
# 16  0.73
# 17  0.69
# 18  0.77
# 19  1.00
